# %%
import pandas as pd

# %%
import json

# %%
import datetime

# %%
# python json 파일 불러오기
with open('./2020_APRIL.json', encoding='utf-8') as t:
    geo = json.load(t)

# %%
# json 파일의 내부를 예쁘게 보기 위해서 pprint 사용
from pprint import pprint

# %%
# json 파일 확인
pprint(geo)
# Out:
# {'timelineObjects': [{'activitySegment': {'activities': [{'activityType': 'WALKING',
#                                                           'probability': 91.83619022369385},
#                                                          {'activityType': 'IN_BUS',
#                                                           'probability': 3.3714357763528824},
#                                                          {'activityType': 'IN_PASSENGER_VEHICLE',
#                                                           'probability': 1.8112488090991974},
#                                                          {'activityType': 'STILL',
#                                                           'probability': 1.2431089766323566},
#                                                          {'activityType': 'RUNNING',
#                                                           'probability': 0.8401322178542614},
#                                                          {'activityType': 'CYCLING',
#                                                           'probability': 0.47733429819345474},
#                                                          {'activityType': 'IN_SUBWAY',
#                                                           'probability': 0.19634715281426907},
#                                                          {'activityType': 'MOTORCYCLING',
#                                                           'probability': 0.0581044121645391},
#                                                          {'activityType': 'IN_TRAIN',
#                                                           'probability': 0.04873166617471725},
#                                                          {'activityType': 'IN_TRAM',
#                                                           'probability': 0.039619492599740624},
#                                                          {'activityType': 'IN_FERRY',
#                                                           'probability': 0.03532948030624539},
#                                                          {'activityType': 'FLYING',
#                                                           'probability': 0.02796297485474497},
#                                                          {'activityType': 'SKIING',
#                                                           'probability': 0.010524245590204373},
#                                                          {'activityType': 'IN_VEHICLE',
#                                                           'probability': 0.0030384760975721292},
#                                                          {'activityType': 'SAILING',
#                                                           'probability': 0.0008978975529316813}],
#                                           'activityType': 'WALKING',
#                                           'confidence': 'HIGH',
#                                           'distance': 1526,
#                                           'duration': {'endTimestampMs': '1585715584809',
#                                                        'startTimestampMs': '1585714240758'},
#                                           'endLocation': {'latitudeE7': 373078866,
#                                                           'longitudeE7': 1268302594},
#                                           'simplifiedRawPath': {'points': [{'accuracyMeters': 4,
#                                                                             'latE7': 373188158,
#                                                                             'lngE7': 1268309680,
#                                                                             'timestampMs': '1585714666000'},
#                                                                            {'accuracyMeters': 150,
#                                                                             'latE7': 373098705,
#                                                                             'lngE7': 1268301809,
#                                                                             'timestampMs': '1585715343365'},
#                                                                            {'accuracyMeters': 150,
#                                                                             'latE7': 373083408,
#                                                                             'lngE7': 1268292423,
#                                                                             'timestampMs': '1585715464318'}]},
#                                           'startLocation': {'latitudeE7': 373204091,
#                                                             'longitudeE7': 1268336199}}},
#                      {'placeVisit': {'centerLatE7': 373078652,
#                                      'centerLngE7': 1268304404,
#                                      'duration': {'endTimestampMs': '1585724653335',
#                                                   'startTimestampMs': '1585715584809'},
#                                      'editConfirmationStatus': 'NOT_CONFIRMED',
#                                      'location': {'address': '대한민국 경기도 안산시 단원구 '
#                                                              '호수동 광덕대로 130',
#                                                   'latitudeE7': 373078384,
#                                                   'locationConfidence': 83.97217,
#                                                   'longitudeE7': 1268304749,
#                                                   'name': '130',
#                                                   'placeId': 'ChIJXXkZ1_tuezURHrNqK84649M',
#                                                   'sourceInfo': {'deviceTag': 959293159}},
#                                      'otherCandidateLocations': [{'latitudeE7': 373079350,
#                                                                   'locationConfidence': 6.329895,
#                                                                   'longitudeE7': 1268303260,
#                                                                   'placeId': 'ChIJfYJAfvluezURi0pYIyjpjO8'},
#                                                                  {'latitudeE7': 373079400,
#                                                                   'locationConfidence': 3.6505659,
#                                                                   'longitudeE7': 1268303430,
#                                                                   'placeId': 'ChIJXXkZ1_tuezUR2vcXzgQdzr0'},
#                                                                  {'latitudeE7': 373079023,
#                                                                   'locationConfidence': 1.44702,
#                                                                   'longitudeE7': 1268303001,
#                                                                   'placeId': 'ChIJMSkG4I9vezURJ2wSqKLAlYg'},
#                                                                  {'latitudeE7': 373078823,
#                                                                   'locationConfidence': 0.896095,
#                                                                   'longitudeE7': 1268304859,
#                                                                   'placeId': 'ChIJffIEV1dvezURGRBousAopPc'},
#                                                                  {'latitudeE7': 373080747,
#                                                                   'locationConfidence': 0.8414241,
#                                                                   'longitudeE7': 1268306431,
#                                                                   'placeId': 'ChIJXXkZ1_tuezUR3Sy9WYSGU2I'},
#                                                                  {'latitudeE7': 373078853,
#                                                                   'locationConfidence': 0.548048,
#                                                                   'longitudeE7': 1268305131,
#                                                                   'placeId': 'ChIJQdDA1ftuezURUE0pCQbNhk0'}],
#                                      'placeConfidence': 'HIGH_CONFIDENCE',
#                                      'visitConfidence': 90}},
#                      {'activitySegment': {'activities': [{'activityType': 'IN_BUS',
#                                                           'probability': 61.790066957473755},
#                                                          {'activityType': 'WALKING',
#                                                           'probability': 32.407647371292114},
#                                                          {'activityType': 'IN_PASSENGER_VEHICLE',
#                                                           'probability': 2.8200477361679077},
#                                                          {'activityType': 'STILL',
#                                                           'probability': 0.9548024274408817},
#                                                          {'activityType': 'IN_SUBWAY',
#                                                           'probability': 0.7567099761217833},
#                                                          {'activityType': 'CYCLING',
#                                                           'probability': 0.6247140932828188},
#                                                          {'activityType': 'IN_TRAM',
#                                                           'probability': 0.19412017427384853},
#                                                          {'activityType': 'IN_TRAIN',
#                                                           'probability': 0.15998028684407473},
#                                                          {'activityType': 'RUNNING',
#                                                           'probability': 0.15750681050121784},
#                                                          {'activityType': 'MOTORCYCLING',
#                                                           'probability': 0.08647788199596107},
#                                                          {'activityType': 'FLYING',
#                                                           'probability': 0.017388429841957986},
#                                                          {'activityType': 'IN_VEHICLE',
#                                                           'probability': 0.014834820467513055},
#                                                          {'activityType': 'IN_FERRY',
#                                                           'probability': 0.012890785001218319},
#                                                          {'activityType': 'SKIING',
#                                                           'probability': 0.0027600231987889856},
#                                                          {'activityType': 'SAILING',
#                                                           'probability': 4.7486355470027775e-05}],
#                                           'activityType': 'IN_BUS',
#                                           'confidence': 'MEDIUM',
#                                           'distance': 2371,
#                                           'duration': {'endTimestampMs': '1585725637278',
#                                                        'startTimestampMs': '1585724653335'},
#                                           'endLocation': {'latitudeE7': 373180679,
#                                                           'longitudeE7': 1268371374},
#                                           'simplifiedRawPath': {'points': [{'accuracyMeters': 22,
#                                                                             'latE7': 373077177,
#                                                                             'lngE7': 1268320049,
#                                                                             'timestampMs': '1585724702046'},
#                                                                            {'accuracyMeters': 100,
#                                                                             'latE7': 373077408,
#                                                                             'lngE7': 1268353094,
#                                                                             'timestampMs': '1585724826726'},
#                                                                            {'accuracyMeters': 15,
#                                                                             'latE7': 373145846,
#                                                                             'lngE7': 1268366987,
#                                                                             'timestampMs': '1585725122026'},
#                                                                            {'accuracyMeters': 40,
#                                                                             'latE7': 373167107,
#                                                                             'lngE7': 1268386762,
#                                                                             'timestampMs': '1585725243060'},
#                                                                            {'accuracyMeters': 77,
#                                                                             'latE7': 373173821,
#                                                                             'lngE7': 1268425483,
#                                                                             'timestampMs': '1585725317574'},
#                                                                            {'accuracyMeters': 15,
#                                                                             'latE7': 373173991,
#                                                                             'lngE7': 1268374975,
#                                                                             'timestampMs': '1585725564837'}]},
#                                           'startLocation': {'latitudeE7': 373074977,
#                                                             'longitudeE7': 1268308870},
#                                           'transitPath': {'hexRgbColor': '374FF2',
#                                                           'name': '77',
#                                                           'transitStops': [{'latitudeE7': 373073690,
#                                                                             'longitudeE7': 1268336560,
#                                                                             'name': 'Prugio '
#                                                                                     'Apt. '
#                                                                                     'I',
#                                                                             'placeId': 'ChIJY_dwDvtuezUR5gCqoxBLQkg'},
#                                                                            {'latitudeE7': 373162780,
#                                                                             'longitudeE7': 1268389000,
#                                                                             'name': 'Jungang '
#                                                                                     'Station',
#                                                                             'placeId': 'ChIJk-ZdhxtvezURgEDL1aWsIdI'}]}}},
#                      {'placeVisit': {'centerLatE7': 373188150,
#                                      'centerLngE7': 1268376233,
#                                      'duration': {'endTimestampMs': '1585727243329',
#                                                   'startTimestampMs': '1585725637278'},
#                                      'editConfirmationStatus': 'NOT_CONFIRMED',
#                                      'location': {'address': '대한민국 경기도 안산시 단원구 '
#                                                              '단원구 고잔동 539-1',
#                                                   'latitudeE7': 373187138,
#                                                   'locationConfidence': 44.604797,
#                                                   'longitudeE7': 1268376187,
#                                                   'name': 'Starbucks',
#                                                   'placeId': 'ChIJs6d4HBtvezUR9QMbG3bnB3s',
#                                                   'sourceInfo': {'deviceTag': 959293159}},
#                                      'otherCandidateLocations': [{'latitudeE7': 373187740,
#                                                                   'locationConfidence': 26.858677,
#                                                                   'longitudeE7': 1268375823,
#                                                                   'placeId': 'ChIJs6d4HBtvezURlBZM2Nl8Rcc'},
#                                                                  {'latitudeE7': 373187138,
#                                                                   'locationConfidence': 16.01706,
#                                                                   'longitudeE7': 1268376187,
#                                                                   'placeId': 'ChIJs6d4HBtvezURFmTmua8XOac'},
#                                                                  {'latitudeE7': 373188060,
#                                                                   'locationConfidence': 3.1508973,
#                                                                   'longitudeE7': 1268375610,
#                                                                   'placeId': 'ChIJX6hqHBtvezURNyxEslj355E'},
#                                                                  {'latitudeE7': 373187652,
#                                                                   'locationConfidence': 1.7699306,
#                                                                   'longitudeE7': 1268376315,
#                                                                   'placeId': 'ChIJFT0XNhpvezUR3590n_OBFoE'},
#                                                                  {'latitudeE7': 373187138,
#                                                                   'locationConfidence': 1.2948953,
#                                                                   'longitudeE7': 1268376187,
#                                                                   'placeId': 'ChIJs6d4HBtvezURM3KSa5q5VfI'},
#                                                                  {'latitudeE7': 373186181,
#                                                                   'locationConfidence': 1.2655241,
#                                                                   'longitudeE7': 1268365736,
#                                                                   'placeId': 'ChIJ4QllOhtvezURqcBXf3A57hQ'},
#                                                                  {'latitudeE7': 373185349,
#                                                                   'locationConfidence': 1.1995181,
#                                                                   'longitudeE7': 1268380276,
#                                                                   'placeId': 'ChIJlzZwBBtvezURKNIu66dPP6Q'},
#                                                                  {'latitudeE7': 373160820,
#                                                                   'locationConfidence': 1.1782074,
#                                                                   'longitudeE7': 1268389664,
#                                                                   'placeId': 'ChIJCeCHfRxvezURZSicSU7_gdA'},
#                                                                  {'latitudeE7': 373187012,
#                                                                   'locationConfidence': 0.58547217,
#                                                                   'longitudeE7': 1268375929,
#                                                                   'placeId': 'ChIJ7ZGlBFdvezURIkKoqglUiPY'}],
#                                      'placeConfidence': 'LOW_CONFIDENCE',
#                                      'visitConfidence': 90}},
#                      {'activitySegment': {'activities': [{'activityType': 'WALKING',
#                                                           'probability': 92.4320936203003},
#                                                          {'activityType': 'IN_BUS',
#                                                           'probability': 4.3157875537872314},
#                                                          {'activityType': 'IN_PASSENGER_VEHICLE',
#                                                           'probability': 1.5036584809422493},
#                                                          {'activityType': 'STILL',
#                                                           'probability': 1.0679305531084538},
#                                                          {'activityType': 'IN_SUBWAY',
#                                                           'probability': 0.2452127868309617},
#                                                          {'activityType': 'CYCLING',
#                                                           'probability': 0.17083026468753815},
#                                                          {'activityType': 'RUNNING',
#                                                           'probability': 0.1094687613658607},
#                                                          {'activityType': 'MOTORCYCLING',
#                                                           'probability': 0.06290871533565223},
#                                                          {'activityType': 'IN_TRAIN',
#                                                           'probability': 0.03364264266565442},
#                                                          {'activityType': 'IN_TRAM',
#                                                           'probability': 0.023541224072687328},
#                                                          {'activityType': 'IN_FERRY',
#                                                           'probability': 0.017596353427506983},
#                                                          {'activityType': 'FLYING',
#                                                           'probability': 0.013353856047615409},
#                                                          {'activityType': 'IN_VEHICLE',
#                                                           'probability': 0.0019366079868632369},
#                                                          {'activityType': 'SKIING',
#                                                           'probability': 0.0018172477211919613},
#                                                          {'activityType': 'SAILING',
#                                                           'probability': 0.00022042436285119038}],
#                                           'activityType': 'WALKING',
#                                           'confidence': 'HIGH',
#                                           'distance': 266,
#                                           'duration': {'endTimestampMs': '1585727485838',
#                                                        'startTimestampMs': '1585727243329'},
#                                           'endLocation': {'latitudeE7': 373184207,
#                                                           'longitudeE7': 1268342583},
#                                           'startLocation': {'latitudeE7': 373187300,
#                                                             'longitudeE7': 1268372429}}},
#                      {'placeVisit': {'centerLatE7': 373187556,
#                                      'centerLngE7': 1268340467,
#                                      'duration': {'endTimestampMs': '1585728290256',
#                                                   'startTimestampMs': '1585727485838'},
#                                      'editConfirmationStatus': 'NOT_CONFIRMED',
#                                      'location': {'latitudeE7': 373186948,
#                                                   'locationConfidence': 83.159996,
#                                                   'longitudeE7': 1268342242,
#                                                   'name': '다이소 고잔점',
#                                                   'placeId': 'ChIJWUjslgRvezUR47hg-FiDkQU',
#                                                   'sourceInfo': {'deviceTag': 959293159}},
#                                      'otherCandidateLocations': [{'latitudeE7': 373203621,
#                                                                   'locationConfidence': 8.724857,
#                                                                   'longitudeE7': 1268337173,
#                                                                   'placeId': 'ChIJg4CP-ARvezURnRm2RyJuPGo'},
#                                                                  {'latitudeE7': 373179793,
#                                                                   'locationConfidence': 3.205133,
#                                                                   'longitudeE7': 1268344905,
#                                                                   'placeId': 'ChIJufQmoARvezURYh2bIsZ4rdU'},
#                                                                  {'latitudeE7': 373186078,
#                                                                   'locationConfidence': 0.9724858,
#                                                                   'longitudeE7': 1268332726,
#                                                                   'placeId': 'ChIJUzZpfgRvezURoVdwrx8r9ok'},
#                                                                  {'latitudeE7': 373185638,
#                                                                   'locationConfidence': 0.7481212,
#                                                                   'longitudeE7': 1268341830,
#                                                                   'placeId': 'ChIJWUjslgRvezURnKq3tvGchig'},
#                                                                  {'latitudeE7': 373182283,
#                                                                   'locationConfidence': 0.6301248,
#                                                                   'longitudeE7': 1268336428,
#                                                                   'placeId': 'ChIJGRNmrwRvezURpK3sKg2n5CE'},
#                                                                  {'latitudeE7': 373189140,
#                                                                   'locationConfidence': 0.5036322,
#                                                                   'longitudeE7': 1268342412,
#                                                                   'placeId': 'ChIJ71_bLQVvezURPYvyS56Cjm0'}],
#                                      'placeConfidence': 'MEDIUM_CONFIDENCE',
#                                      'visitConfidence': 89}},
#                      {'activitySegment': {'activities': [{'activityType': 'WALKING',
#                                                           'probability': 89.44823741912842},
#                                                          {'activityType': 'STILL',
#                                                           'probability': 6.540998071432114},
#                                                          {'activityType': 'IN_PASSENGER_VEHICLE',
#                                                           'probability': 1.7282845452427864},
#                                                          {'activityType': 'IN_BUS',
#                                                           'probability': 1.6741832718253136},
#                                                          {'activityType': 'IN_SUBWAY',
#                                                           'probability': 0.15650064451619983},
#                                                          {'activityType': 'CYCLING',
#                                                           'probability': 0.15549035742878914},
#                                                          {'activityType': 'RUNNING',
#                                                           'probability': 0.09842886356636882},
#                                                          {'activityType': 'MOTORCYCLING',
#                                                           'probability': 0.08961237617768347},
#                                                          {'activityType': 'IN_TRAIN',
#                                                           'probability': 0.060453725745901465},
#                                                          {'activityType': 'FLYING',
#                                                           'probability': 0.021190423285588622},
#                                                          {'activityType': 'IN_FERRY',
#                                                           'probability': 0.016307008627336472},
#                                                          {'activityType': 'IN_TRAM',
#                                                           'probability': 0.007091042061802},
#                                                          {'activityType': 'IN_VEHICLE',
#                                                           'probability': 0.0017094953363994136},
#                                                          {'activityType': 'SKIING',
#                                                           'probability': 0.0010391479918325786},
#                                                          {'activityType': 'SAILING',
#                                                           'probability': 0.00046713653318875004}],
#                                           'activityType': 'WALKING',
#                                           'confidence': 'HIGH',
#                                           'distance': 101,
#                                           'duration': {'endTimestampMs': '1585728438260',
#                                                        'startTimestampMs': '1585728290256'},
#                                           'endLocation': {'latitudeE7': 373201526,
#                                                           'longitudeE7': 1268329424},
#                                           'startLocation': {'latitudeE7': 373193152,
#                                                             'longitudeE7': 1268333975}}},
#                      {'placeVisit': {'centerLatE7': 373204640,
#                                      'centerLngE7': 1268336935,
#                                      'duration': {'endTimestampMs': '1585778216915',
#                                                   'startTimestampMs': '1585728438260'},
#                                      'editConfirmationStatus': 'NOT_CONFIRMED',
#                                      'location': {'address': '대한민국 경기도 안산시 단원구 '
#                                                              '고잔동 당곡로 33',
#                                                   'latitudeE7': 373202124,
#                                                   'locationConfidence': 96.1185,
#                                                   'longitudeE7': 1268331436,
#                                                   'name': '33',
#                                                   'placeId': 'ChIJg4CP-ARvezURnRm2RyJuPGo',
#                                                   'sourceInfo': {'deviceTag': 959293159}},
#                                      'otherCandidateLocations': [{'latitudeE7': 373189140,
#                                                                   'locationConfidence': 1.738952,
#                                                                   'longitudeE7': 1268342412,
#                                                                   'placeId': 'ChIJ4VJcgANvezUR1zUss_CC9uk'},
#                                                                  {'latitudeE7': 373203401,
#                                                                   'locationConfidence': 0.871109,
#                                                                   'longitudeE7': 1268332128,
#                                                                   'placeId': 'ChIJS1862wNvezURTJvS4JALQaA'},
#                                                                  {'latitudeE7': 373193765,
#                                                                   'locationConfidence': 0.30775902,
#                                                                   'longitudeE7': 1268348669,
#                                                                   'placeId': 'ChIJW0M3PM9vezUREVyFdZsWnS8'},
#                                                                  {'latitudeE7': 373203196,
#                                                                   'locationConfidence': 0.1657987,
#                                                                   'longitudeE7': 1268321367,
#                                                                   'placeId': 'ChIJ4S_DRQRvezURbYaTqubfb2A'}],
#                                      'placeConfidence': 'HIGH_CONFIDENCE',
#                                      'visitConfidence': 87}},
#                      {'activitySegment': {'activities': [{'activityType': 'IN_PASSENGER_VEHICLE',
#                                                           'probability': 97.6874053478241},
#                                                          {'activityType': 'WALKING',
#                                                           'probability': 1.0059993714094162},
#                                                          {'activityType': 'STILL',
#                                                           'probability': 1.001925766468048},
#                                                          {'activityType': 'MOTORCYCLING',
#                                                           'probability': 0.08980390266515315},
#                                                          {'activityType': 'IN_BUS',
#                                                           'probability': 0.07677573594264686},
#                                                          {'activityType': 'CYCLING',
#                                                           'probability': 0.06276685162447393},
#                                                          {'activityType': 'IN_FERRY',
#                                                           'probability': 0.02595897822175175},
#                                                          {'activityType': 'RUNNING',
#                                                           'probability': 0.017759409092832357},
#                                                          {'activityType': 'FLYING',
#                                                           'probability': 0.015667127445340157},
#                                                          {'activityType': 'IN_TRAIN',
#                                                           'probability': 0.006848789053037763},
#                                                          {'activityType': 'SKIING',
#                                                           'probability': 0.0031638719519833103},
#                                                          {'activityType': 'SAILING',
#                                                           'probability': 0.0028356917027849704},
#                                                          {'activityType': 'IN_TRAM',
#                                                           'probability': 0.002588782263046596},
#                                                          {'activityType': 'IN_SUBWAY',
#                                                           'probability': 0.00048019310270319693},
#                                                          {'activityType': 'IN_VEHICLE',
#                                                           'probability': 1.946700507460264e-05}],
#                                           'activityType': 'IN_PASSENGER_VEHICLE',
#                                           'confidence': 'HIGH',
#                                           'distance': 23369,
#                                           'duration': {'endTimestampMs': '1585781365637',
#                                                        'startTimestampMs': '1585778216915'},
#                                           'endLocation': {'latitudeE7': 371315747,
#                                                           'longitudeE7': 1268632345},
#                                           'parkingEvent': {'location': {'accuracyMetres': 54,
#                                                                         'latitudeE7': 371316641,
#                                                                         'longitudeE7': 1268645547},
#                                                            'timestampMs': '1585781474084'},
#                                           'simplifiedRawPath': {'points': [{'accuracyMeters': 48,
#                                                                             'latE7': 373160303,
#                                                                             'lngE7': 1268444465,
#                                                                             'timestampMs': '1585778584933'},
#                                                                            {'accuracyMeters': 3,
#                                                                             'latE7': 373158808,
#                                                                             'lngE7': 1268478946,
#                                                                             'timestampMs': '1585778615999'},
#                                                                            {'accuracyMeters': 3,
#                                                                             'latE7': 372491887,
#                                                                             'lngE7': 1268937771,
#                                                                             'timestampMs': '1585779482000'},
#                                                                            {'accuracyMeters': 3,
#                                                                             'latE7': 372292990,
#                                                                             'lngE7': 1268786223,
#                                                                             'timestampMs': '1585780203999'},
#                                                                            {'accuracyMeters': 3,
#                                                                             'latE7': 372237232,
#                                                                             'lngE7': 1268758576,
#                                                                             'timestampMs': '1585780281999'},
#                                                                            {'accuracyMeters': 16,
#                                                                             'latE7': 371409950,
#                                                                             'lngE7': 1268607932,
#                                                                             'timestampMs': '1585781215055'},
#                                                                            {'accuracyMeters': 3,
#                                                                             'latE7': 371340688,
#                                                                             'lngE7': 1268634338,
#                                                                             'timestampMs': '1585781322999'}]},
#                                           'startLocation': {'latitudeE7': 373209334,
#                                                             'longitudeE7': 1268342789}}},
#                      {'placeVisit': {'centerLatE7': 371315175,
#                                      'centerLngE7': 1268636500,
#                                      'duration': {'endTimestampMs': '1585782126155',
#                                                   'startTimestampMs': '1585781365637'},
#                                      'editConfirmationStatus': 'NOT_CONFIRMED',
#                                      'location': {'address': '대한민국 경기도 화성시 팔탄면 '
#                                                              '덕우리 216',
#                                                   'latitudeE7': 371316094,
#                                                   'locationConfidence': 26.552599,
#                                                   'longitudeE7': 1268635695,
#                                                   'name': '216',
#                                                   'placeId': 'ChIJk_iMEPQTezURxCOPGtqm_w0',
#                                                   'sourceInfo': {'deviceTag': 959293159}},
#                                      'otherCandidateLocations': [{'latitudeE7': 371316103,
#                                                                   'locationConfidence': 22.229103,
#                                                                   'longitudeE7': 1268634850,
#                                                                   'placeId': 'ChIJO9BxEPQTezURgN5NbnSKxgs'},
#                                                                  {'latitudeE7': 371314551,
#                                                                   'locationConfidence': 21.913908,
#                                                                   'longitudeE7': 1268634603,
#                                                                   'placeId': 'ChIJ_7jgGvQTezURa_77OKhWVAU'},
#                                                                  {'latitudeE7': 371321924,
#                                                                   'locationConfidence': 10.962865,
#                                                                   'longitudeE7': 1268633885,
#                                                                   'placeId': 'ChIJcbRUbfQTezURSa4F0qYg2Vg'},
#                                                                  {'latitudeE7': 371331268,
#                                                                   'locationConfidence': 5.7374263,
#                                                                   'longitudeE7': 1268628186,
#                                                                   'placeId': 'ChIJD8r1ePQTezURmkjnCUlDdtA'},
#                                                                  {'latitudeE7': 371338027,
#                                                                   'locationConfidence': 2.4117348,
#                                                                   'longitudeE7': 1268643717,
#                                                                   'placeId': 'ChIJZaQf7PQTezUR5o7qRoetGfc'},
#                                                                  {'latitudeE7': 371315858,
#                                                                   'locationConfidence': 1.8824751,
#                                                                   'longitudeE7': 1268627429,
#                                                                   'placeId': 'ChIJ00hGB_QTezURGCp6ltVtigU'},
#                                                                  {'latitudeE7': 371307812,
#                                                                   'locationConfidence': 1.791645,
#                                                                   'longitudeE7': 1268639397,
#                                                                   'placeId': 'ChIJdx9soPYTezURQ0KohphrT8c'},
#                                                                  {'latitudeE7': 371316206,
#                                                                   'locationConfidence': 1.619712,
#                                                                   'longitudeE7': 1268627646,
#                                                                   'placeId': 'ChIJ00hGB_QTezURLcszMOWGCvE'},
#                                                                  {'latitudeE7': 371334078,
#                                                                   'locationConfidence': 1.3660711,
#                                                                   'longitudeE7': 1268636517,
#                                                                   'placeId': 'ChIJnzh2ifQTezURDf2MR31vIAs'}],
#                                      'placeConfidence': 'LOW_CONFIDENCE',
#                                      'visitConfidence': 69}},
#                      {'placeVisit': {'centerLatE7': 371328833,
#                                      'centerLngE7': 1268706100,
#                                      'duration': {'endTimestampMs': '1585784523933',
#                                                   'startTimestampMs': '1585782126155'},
#                                      'editConfirmationStatus': 'NOT_CONFIRMED',
#                                      'location': {'address': '대한민국 경기도 화성시 팔탄면 '
#                                                              '덕우리 200-12',
#                                                   'latitudeE7': 371329153,
#                                                   'locationConfidence': 20.387121,
#                                                   'longitudeE7': 1268706740,
#                                                   'name': '200-12',
#                                                   'placeId': 'ChIJvZ8L1QoUezURsx9VzytGLOc',
#                                                   'sourceInfo': {'deviceTag': 959293159}},
#                                      'otherCandidateLocations': [{'latitudeE7': 371329614,
#                                                                   'locationConfidence': 18.406328,
#                                                                   'longitudeE7': 1268705844,
#                                                                   'placeId': 'ChIJUYr81AoUezUR4sPxh9IdjgY'},
#                                                                  {'latitudeE7': 371328660,
#                                                                   'locationConfidence': 15.28409,
#                                                                   'longitudeE7': 1268710754,
#                                                                   'placeId': 'ChIJe9xQKwsUezURePX4OMd3d1Q'},
#                                                                  {'latitudeE7': 371327955,
#                                                                   'locationConfidence': 14.035712,
#                                                                   'longitudeE7': 1268704822,
#                                                                   'placeId': 'ChIJURCl1goUezUREqGvHsrObn0'},
#                                                                  {'latitudeE7': 371330355,
#                                                                   'locationConfidence': 12.654906,
#                                                                   'longitudeE7': 1268706103,
#                                                                   'placeId': 'ChIJs3wo1QoUezURfbUrY8IPXRA'},
#                                                                  {'latitudeE7': 371326939,
#                                                                   'locationConfidence': 11.643202,
#                                                                   'longitudeE7': 1268708810,
#                                                                   'placeId': 'ChIJn-4mKgsUezURd_JAztIoLEw'},
#                                                                  {'latitudeE7': 371330146,
#                                                                   'locationConfidence': 2.291397,
#                                                                   'longitudeE7': 1268699264,
#                                                                   'placeId': 'ChIJRfOEzgoUezURlE-xYREu4JM'},
#                                                                  {'latitudeE7': 371325254,
#                                                                   'locationConfidence': 2.1360145,
#                                                                   'longitudeE7': 1268711660,
# ...
#                                                                   'placeId': 'ChIJg4CP-ARvezUREmPI39bNYPE'},
#                                                                  {'latitudeE7': 373203401,
#                                                                   'locationConfidence': 0.1902802,
#                                                                   'longitudeE7': 1268332128,
#                                                                   'placeId': 'ChIJS1862wNvezURTJvS4JALQaA'},
#                                                                  {'latitudeE7': 373188958,
#                                                                   'locationConfidence': 0.070316344,
#                                                                   'longitudeE7': 1268348793,
#                                                                   'placeId': 'ChIJ-6trxwRvezURtzEeMHN4K5s'},
#                                                                  {'latitudeE7': 373210270,
#                                                                   'locationConfidence': 0.06964068,
#                                                                   'longitudeE7': 1268352160,
#                                                                   'placeId': 'ChIJx_DeNwVvezURUpjTEqFnmqw'}],
#                                      'placeConfidence': 'HIGH_CONFIDENCE',
#                                      'visitConfidence': 93}},
#                      {'activitySegment': {'activities': [{'activityType': 'WALKING',
#                                                           'probability': 61.30746006965637},
#                                                          {'activityType': 'STILL',
#                                                           'probability': 27.36918032169342},
#                                                          {'activityType': 'IN_SUBWAY',
#                                                           'probability': 10.322906821966171},
#                                                          {'activityType': 'IN_PASSENGER_VEHICLE',
#                                                           'probability': 0.37118413019925356},
#                                                          {'activityType': 'IN_BUS',
#                                                           'probability': 0.3035795409232378},
#                                                          {'activityType': 'IN_TRAIN',
#                                                           'probability': 0.17438750946894288},
#                                                          {'activityType': 'RUNNING',
#                                                           'probability': 0.053193827625364065},
#                                                          {'activityType': 'CYCLING',
#                                                           'probability': 0.039847855805419385},
#                                                          {'activityType': 'MOTORCYCLING',
#                                                           'probability': 0.028950176783837378},
#                                                          {'activityType': 'IN_TRAM',
#                                                           'probability': 0.014807531260885298},
#                                                          {'activityType': 'IN_FERRY',
#                                                           'probability': 0.007339065632550046},
#                                                          {'activityType': 'FLYING',
#                                                           'probability': 0.005807914931210689},
#                                                          {'activityType': 'IN_VEHICLE',
#                                                           'probability': 0.000789456407801481},
#                                                          {'activityType': 'SKIING',
#                                                           'probability': 0.0002981894795084372},
#                                                          {'activityType': 'SAILING',
#                                                           'probability': 0.000265230255536153}],
#                                           'activityType': 'WALKING',
#                                           'confidence': 'MEDIUM',
#                                           'distance': 414,
#                                           'duration': {'endTimestampMs': '1588240719931',
#                                                        'startTimestampMs': '1588240205458'},
#                                           'endLocation': {'latitudeE7': 373163214,
#                                                           'longitudeE7': 1268388905,
#                                                           'sourceInfo': {'deviceTag': 959293159}},
#                                           'startLocation': {'latitudeE7': 373177628,
#                                                             'longitudeE7': 1268351506,
#                                                             'sourceInfo': {'deviceTag': 959293159}}}},
#                      {'activitySegment': {'activities': [{'activityType': 'IN_SUBWAY',
#                                                           'probability': 78.91974449157715},
#                                                          {'activityType': 'WALKING',
#                                                           'probability': 13.904009759426117},
#                                                          {'activityType': 'STILL',
#                                                           'probability': 3.6072853952646255},
#                                                          {'activityType': 'IN_PASSENGER_VEHICLE',
#                                                           'probability': 1.7542758956551552},
#                                                          {'activityType': 'IN_BUS',
#                                                           'probability': 1.2702427804470062},
#                                                          {'activityType': 'IN_TRAIN',
#                                                           'probability': 0.20214864052832127},
#                                                          {'activityType': 'MOTORCYCLING',
#                                                           'probability': 0.17799956258386374},
#                                                          {'activityType': 'IN_TRAM',
#                                                           'probability': 0.04940858343616128},
#                                                          {'activityType': 'RUNNING',
#                                                           'probability': 0.03203934174962342},
#                                                          {'activityType': 'CYCLING',
#                                                           'probability': 0.029086804715916514},
#                                                          {'activityType': 'IN_FERRY',
#                                                           'probability': 0.022985767282079905},
#                                                          {'activityType': 'FLYING',
#                                                           'probability': 0.015418793191201985},
#                                                          {'activityType': 'SAILING',
#                                                           'probability': 0.005502404746948741},
#                                                          {'activityType': 'SKIING',
#                                                           'probability': 0.00494554296892602},
#                                                          {'activityType': 'IN_VEHICLE',
#                                                           'probability': 0.0049123696953756735}],
#                                           'activityType': 'IN_SUBWAY',
#                                           'confidence': 'HIGH',
#                                           'distance': 40766,
#                                           'duration': {'endTimestampMs': '1588246328783',
#                                                        'startTimestampMs': '1588240719931'},
#                                           'endLocation': {'latitudeE7': 375755879,
#                                                           'longitudeE7': 1270310941,
#                                                           'sourceInfo': {'deviceTag': 959293159}},
#                                           'simplifiedRawPath': {'points': [{'accuracyMeters': 49,
#                                                                             'latE7': 373508518,
#                                                                             'lngE7': 1269257063,
#                                                                             'timestampMs': '1588241702718'},
#                                                                            {'accuracyMeters': 39,
#                                                                             'latE7': 373584673,
#                                                                             'lngE7': 1269337678,
#                                                                             'timestampMs': '1588241823802'},
#                                                                            {'accuracyMeters': 150,
#                                                                             'latE7': 373728681,
#                                                                             'lngE7': 1269425202,
#                                                                             'timestampMs': '1588242065435'},
#                                                                            {'accuracyMeters': 19,
#                                                                             'latE7': 373943867,
#                                                                             'lngE7': 1269638944,
#                                                                             'timestampMs': '1588242424178'},
#                                                                            {'accuracyMeters': 106,
#                                                                             'latE7': 374516675,
#                                                                             'lngE7': 1270019834,
#                                                                             'timestampMs': '1588243309789'},
#                                                                            {'accuracyMeters': 21,
#                                                                             'latE7': 375033547,
#                                                                             'lngE7': 1269803788,
#                                                                             'timestampMs': '1588243976790'},
#                                                                            {'accuracyMeters': 20,
#                                                                             'latE7': 375225032,
#                                                                             'lngE7': 1269746405,
#                                                                             'timestampMs': '1588244222314'},
#                                                                            {'accuracyMeters': 227,
#                                                                             'latE7': 375285013,
#                                                                             'lngE7': 1269670846,
#                                                                             'timestampMs': '1588244343697'},
#                                                                            {'accuracyMeters': 36,
#                                                                             'latE7': 375447206,
#                                                                             'lngE7': 1269720896,
#                                                                             'timestampMs': '1588244585734'},
#                                                                            {'accuracyMeters': 36,
#                                                                             'latE7': 375556178,
#                                                                             'lngE7': 1269722230,
#                                                                             'timestampMs': '1588244838410'},
#                                                                            {'accuracyMeters': 14,
#                                                                             'latE7': 375793111,
#                                                                             'lngE7': 1270437215,
#                                                                             'timestampMs': '1588245699155'},
#                                                                            {'accuracyMeters': 23,
#                                                                             'latE7': 375781184,
#                                                                             'lngE7': 1270319570,
#                                                                             'timestampMs': '1588246025156'}]},
#                                           'startLocation': {'latitudeE7': 373163214,
#                                                             'longitudeE7': 1268388905,
#                                                             'sourceInfo': {'deviceTag': 959293159}}}},
#                      {'placeVisit': {'duration': {'endTimestampMs': '1588397819033',
#                                                   'startTimestampMs': '1588246328783'},
#                                      'editConfirmationStatus': 'CONFIRMED',
#                                      'location': {'latitudeE7': 375756909,
#                                                   'locationConfidence': 100.0,
#                                                   'longitudeE7': 1270307919,
#                                                   'name': '가산프라스틱',
#                                                   'placeId': 'ChIJZTn7OK28fDURRGsGlP6xM2I'},
#                                      'otherCandidateLocations': [{'latitudeE7': 375757034,
#                                                                   'locationConfidence': 2.1990657,
#                                                                   'longitudeE7': 1270308167,
#                                                                   'placeId': 'ChIJ-agnOa28fDURAAAAAAAAAAA',
#                                                                   'semanticType': 'TYPE_HOME'},
#                                                                  {'latitudeE7': 375761860,
#                                                                   'locationConfidence': 1.8120766,
#                                                                   'longitudeE7': 1270306720,
#                                                                   'placeId': 'ChIJT-IzFa28fDUROjKSm8uTbOM'},
#                                                                  {'latitudeE7': 375757637,
#                                                                   'locationConfidence': 1.6761292,
#                                                                   'longitudeE7': 1270307465,
#                                                                   'placeId': 'ChIJuV7aOK28fDURedNFJLr4Wd0'},
#                                                                  {'latitudeE7': 375759410,
#                                                                   'locationConfidence': 0.85582286,
#                                                                   'longitudeE7': 1270304380,
#                                                                   'placeId': 'ChIJIUI7Qa28fDURok_auszMYSo'}],
#                                      'placeConfidence': 'USER_CONFIRMED',
#                                      'visitConfidence': 100}}]}

# %% [markdown]
# ## 1. 어떤 장소를 많이 갔는가.

# %%
# 원하는 정보만 가져와서 DataFrame으로 만들기 위해 뽑아내는 작업.
# 주소 정보와 이동 정보가 랜덤하게 존재해서 그냥 편하게 try로 처리했다.

# 주소 정보 가져오는 작업
place = []
for i in range(len(geo['timelineObjects'])):
    try:
        latitude = geo['timelineObjects'][i]['placeVisit']['location']['latitudeE7']
        longitude = geo['timelineObjects'][i]['placeVisit']['location']['longitudeE7']
        address = geo['timelineObjects'][i]['placeVisit']['location']['address']
        starttime = geo['timelineObjects'][i]['placeVisit']['duration']['startTimestampMs']
        endtime = geo['timelineObjects'][i]['placeVisit']['duration']['endTimestampMs']
        starttime_date = datetime.datetime.fromtimestamp(int(starttime)/1000)
        endtime_date = datetime.datetime.fromtimestamp(int(endtime)/1000)
        during = endtime_date - starttime_date
        place.append([latitude, longitude, address, during.seconds/3600])
    except:
        pass

# %%
# 위도, 경도, 주소, 기간 dataframe 생성
placedata = pd.DataFrame(place, columns=['latitude', 'longitude', 'address', 'during'])

# %%
placedata
# Out:
#      latitude   longitude                         address     during
# 0   373078384  1268304749   대한민국 경기도 안산시 단원구 호수동 광덕대로 130   2.518889
# 1   373187138  1268376187  대한민국 경기도 안산시 단원구 단원구 고잔동 539-1   0.446111
# 2   373202124  1268331436     대한민국 경기도 안산시 단원구 고잔동 당곡로 33  13.827222
# 3   371316094  1268635695        대한민국 경기도 화성시 팔탄면 덕우리 216   0.211111
# 4   371329153  1268706740     대한민국 경기도 화성시 팔탄면 덕우리 200-12   0.665833
# ..        ...         ...                             ...        ...
# 68  373160650  1268385450            대한민국 경기도 안산시 단원구 고잔동   0.066944
# 69  375745068  1270387406    대한민국 서울특별시 동대문구 용두동 천호대로 133   0.485833
# 70  373202124  1268331436     대한민국 경기도 안산시 단원구 고잔동 당곡로 33  22.367778
# 71  373078384  1268304749   대한민국 경기도 안산시 단원구 호수동 광덕대로 130   2.303611
# 72  373202124  1268331436     대한민국 경기도 안산시 단원구 고잔동 당곡로 33  22.159444
#
# [73 rows x 4 columns]

# %%
# 위도, 경도 기준으로 합산하여 총 방문 시간 알기.
# 내림차순으로 정렬.
placedata.groupby(['latitude', 'longitude']).sum().sort_values(by=['during'], ascending=False)
# Out:
#                           during
# latitude  longitude
# 373202124 1268331436  128.912222
# 375757637 1270307465   79.984722
# 375761860 1270306720   21.348889
# 373078384 1268304749   12.815556
# 373078822 1268304859    4.612778
# 374980362 1270362931    4.494167
# 375414775 1270569489    3.670000
# 373080747 1268306431    3.200278
# 373079023 1268303001    2.590278
# 375843864 1270298618    2.365000
# 375745068 1270387406    2.295000
# 375389565 1270711279    1.959444
# 373102320 1268317760    1.846667
# 373078823 1268304859    1.745556
# 374989754 1270364483    1.728889
# 375834680 1270300680    1.517222
# 375872679 1270290917    1.410278
# 375869221 1270291306    1.123056
# 373160650 1268385450    0.971389
# 375384947 1270734221    0.951389
# 375831836 1270296835    0.737500
# 375838947 1270296862    0.727778
# 371329153 1268706740    0.665833
# 375387444 1270730032    0.643333
# 375848711 1270295316    0.594167
# 375781758 1270345907    0.462778
# 373187138 1268376187    0.446111
# 375757570 1270372410    0.405278
# 375825691 1270266342    0.374444
# 375530170 1269726460    0.264167
# 376152140 1270656120    0.241944
# 371316094 1268635695    0.211111
# 376197240 1270574600    0.208056
# 375003260 1270360870    0.142222
# 375134020 1269264240    0.108889
# 373719637 1269436458    0.105000
# 375445770 1270559910    0.101389
# 375862080 1270297950    0.100556
# 373149240 1268385820    0.092222
# 373178787 1268360893    0.033611

# %%
# 각각의 방문 장소를 방문 기간을 기준으로 내림차순
placedata.sort_values(by=['during'], ascending=False)[:15]
# Out:
#      latitude   longitude                      address     during
# 70  373202124  1268331436  대한민국 경기도 안산시 단원구 고잔동 당곡로 33  22.367778
# 72  373202124  1268331436  대한민국 경기도 안산시 단원구 고잔동 당곡로 33  22.159444
# 30  375761860  1270306720               대한민국 서울특별시 용두동  21.348889
# 27  373202124  1268331436  대한민국 경기도 안산시 단원구 고잔동 당곡로 33  20.477500
# 18  375757637  1270307465   대한민국 서울특별시 동대문구 용두동 119-55  20.143056
# 7   375757637  1270307465   대한민국 서울특별시 동대문구 용두동 119-55  19.152500
# 39  373202124  1268331436  대한민국 경기도 안산시 단원구 고잔동 당곡로 33  17.232222
# 12  375757637  1270307465   대한민국 서울특별시 동대문구 용두동 119-55  16.965278
# 2   373202124  1268331436  대한민국 경기도 안산시 단원구 고잔동 당곡로 33  13.827222
# 22  375757637  1270307465   대한민국 서울특별시 동대문구 용두동 119-55  12.661389
# 54  373202124  1268331436  대한민국 경기도 안산시 단원구 고잔동 당곡로 33  10.876111
# 5   375757637  1270307465   대한민국 서울특별시 동대문구 용두동 119-55   6.386944
# 58  373202124  1268331436  대한민국 경기도 안산시 단원구 고잔동 당곡로 33   6.221389
# 51  373202124  1268331436  대한민국 경기도 안산시 단원구 고잔동 당곡로 33   5.760556
# 23  375757637  1270307465   대한민국 서울특별시 동대문구 용두동 119-55   4.675556

# %%
# 지도 위에 표시하기 위한 folium 가져오기
import folium

# %%
# 연습삼아 찍어보기
m = folium.Map(location=[37.3078652, 126.8304404], zoom_start=17)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 방문기간이 길었던 상위 5개 장소만 지도위에 마커로 찍어보기

m2 = folium.Map(location=[37.5665, 126.9780])

folium.Marker([37.3202124,126.8331436], popup='<b>Timberline Lodge</b>', icon=folium.Icon(color = 'red')).add_to(m2)
folium.Marker([37.5757637,127.0307465], popup='<b>Timberline Lodge</b>', icon=folium.Icon(color = 'green')).add_to(m2)
folium.Marker([37.5761860,127.0306720], popup='<b>Timberline Lodge</b>', icon=folium.Icon(color = 'black')).add_to(m2)
folium.Marker([37.3078384,126.8304749], popup='<b>Timberline Lodge</b>', icon=folium.Icon(color = 'white')).add_to(m2)
folium.Marker([37.3078822,126.8304859], popup='<b>Timberline Lodge</b>', icon=folium.Icon(color = 'pink')).add_to(m2)

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 방문했던 모든 장소 마커로 찍어보기

m3 = folium.Map(location=[37.5665, 126.9780])

for i in range(placedata.latitude.size):
    folium.Marker([placedata.latitude[i]/1e7 ,placedata.longitude[i]/1e7], popup='<b>Timberline Lodge</b>', icon=folium.Icon(color = 'red')).add_to(m3)

# %%
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2. 어떤 방법으로 얼마나 이동했는가

# %%
# 이동 시간 데이터 가져와보기
geo['timelineObjects'][2]['activitySegment']['duration']['startTimestampMs']
# Out:
# '1585724653335'

# %%
# 원하는 정보만 가져와서 DataFrame으로 만들기 위해 뽑아내는 작업.
# 주소 정보와 이동 정보가 랜덤하게 존재해서 그냥 편하게 try로 처리했다.

# 이동 정보 가져오는 작업

move = []
for i in range(len(geo['timelineObjects'])):
    try:
        activityType = geo['timelineObjects'][i]['activitySegment']['activityType']
        distance = geo['timelineObjects'][i]['activitySegment']['distance']
        starttime = geo['timelineObjects'][i]['activitySegment']['duration']['startTimestampMs']
        endtime = geo['timelineObjects'][i]['activitySegment']['duration']['endTimestampMs']
        starttime_date = datetime.datetime.fromtimestamp(int(starttime)/1000)
        endtime_date = datetime.datetime.fromtimestamp(int(endtime)/1000)
        during = endtime_date - starttime_date
        move.append([activityType, distance, during.seconds/60])
    except:
        pass

# %%
# 이동 형태, 거리, 이동시간 데이터 프레임으로 만들기
move_df = pd.DataFrame(move, columns=['activityType', 'distance', 'during'])

# %%
# 이동거리 km 단위로 보여주기
move_df.distance = move_df.distance/1000

# %%
# 이동시간 min 단위로 보여주기
move_df.during = move_df.during*60

# %%
move_df
# Out:
#              activityType  distance     during
# 0                 WALKING     1.526  22.400000
# 1                  IN_BUS     2.371  16.383333
# 2                 WALKING     0.266   4.033333
# 3                 WALKING     0.101   2.466667
# 4    IN_PASSENGER_VEHICLE    23.369  52.466667
# ..                    ...       ...        ...
# 100               WALKING     0.831  10.900000
# 101               WALKING     1.590  18.966667
# 102               WALKING     1.517  19.166667
# 103               WALKING     0.414   8.566667
# 104             IN_SUBWAY    40.766  93.466667
#
# [105 rows x 3 columns]

# %%
# 칼럼 이름에 단위 포함하도록 칼럼 이름 변경
move_df.rename({'distance' : 'distance(km)', 'during':'during(min)'}, axis=1, inplace=True)

# %%
move_df
# Out:
#              activityType  distance(km)  during(min)
# 0                 WALKING         1.526    22.400000
# 1                  IN_BUS         2.371    16.383333
# 2                 WALKING         0.266     4.033333
# 3                 WALKING         0.101     2.466667
# 4    IN_PASSENGER_VEHICLE        23.369    52.466667
# ..                    ...           ...          ...
# 100               WALKING         0.831    10.900000
# 101               WALKING         1.590    18.966667
# 102               WALKING         1.517    19.166667
# 103               WALKING         0.414     8.566667
# 104             IN_SUBWAY        40.766    93.466667
#
# [105 rows x 3 columns]

# %%
# 이동 형태별 합산
move_df.groupby(['activityType']).sum()
# Out:
#                       distance(km)  during(min)
# activityType
# IN_BUS                       5.878    40.950000
# IN_PASSENGER_VEHICLE        29.531    66.716667
# IN_SUBWAY                  755.533  1567.816667
# WALKING                     54.751   828.600000
